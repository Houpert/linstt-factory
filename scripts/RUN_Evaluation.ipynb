# %%
. path.sh
. cmd.sh

# %%
##### Compile System
AM=$lvcsrRootDir/training/AM/ESTER1_2/mono/tri1_2K_100K/tri1_4K_15K/tri2_5K_200K/tri3_SAT_7K_250K/tri3_SAT_8K_300K
LM_arpa=$lvcsrRootDir/training/LM/LM=UC1/text.ilm.gz
Lang_dir=$lvcsrRootDir/training/AM/ESTER1_2/data/lang
SYSTEM=$lvcsrRootDir/systems/Uc1
. compile_system.sh $AM $LM_arpa $Lang_dir $SYSTEM
# Out:
# arpa2fst --disambig-symbol=#0 --read-symbol-table=/opt/lvcsrPlatform/training/AM/ESTER1_2/data/lang_test_text/words.txt - /opt/lvcsrPlatform/training/AM/ESTER1_2/data/lang_test_text/G.fst
# LOG (arpa2fst[5.3.87~1395-96cb]:Read():arpa-file-parser.cc:94) Reading \data\ section.
# LOG (arpa2fst[5.3.87~1395-96cb]:HeaderAvailable():arpa-lm-compiler.cc:300) Reverting to slower state tracking because model is large: 5-gram with symbols up to 117194
# LOG (arpa2fst[5.3.87~1395-96cb]:Read():arpa-file-parser.cc:149) Reading \1-grams: section.
# WARNING (arpa2fst[5.3.87~1395-96cb]:Read():arpa-file-parser.cc:219) line 27 [-2.036629	levesque	-0.740363] skipped: word 'levesque' not in symbol table
# WARNING (arpa2fst[5.3.87~1395-96cb]:Read():arpa-file-parser.cc:219) line 59 [-2.191531	alin	-0.602060] skipped: word 'alin' not in symbol table
# LOG (arpa2fst[5.3.87~1395-96cb]:Read():arpa-file-parser.cc:149) Reading \2-grams: section.
# ...
